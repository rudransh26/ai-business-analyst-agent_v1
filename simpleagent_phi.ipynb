# %%
# %pip install uv
# Out:
# c:\Users\singharu\OneDrive - TFL Ledertechnik GmbH\Documents\Learning\Agents\venv\Scripts\python.exe: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 get_ipython().run_line_magic('pip', 'install uv')
# ----> 2 import uv
#
# ModuleNotFoundError: No module named 'uv'
